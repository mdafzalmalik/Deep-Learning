# %% [markdown]
# Back-Prop with Regression Problem

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame([[8,8,4], [7,9,5], [6,10,6], [5,12,7]], columns = ["cgpa", "resume_score", "lpa"])

# %%
df
# Out:
#    cgpa  resume_score  lpa
# 0     8             8    4
# 1     7             9    5
# 2     6            10    6
# 3     5            12    7

# %%
def initialize_params(layer_dims):
    parameters = {}
    L = len(layer_dims)

    for l in range(1, L):
        parameters["w" + str(l)] = np.ones((layer_dims[l-1], layer_dims[l]))*0.1
        parameters["b" + str(l)] = np.zeros((layer_dims[l], 1))

    return parameters

# %%
initialize_params([2, 2, 1])
# Out:
# {'w1': array([[0.1, 0.1],
#         [0.1, 0.1]]),
#  'b1': array([[0.],
#         [0.]]),
#  'w2': array([[0.1],
#         [0.1]]),
#  'b2': array([[0.]])}

# %%
# calculate the output of given neuron
def linear_forward(A_prev, w, b):  
    z = np.dot(w.T, A_prev) + b
    return z

# %%
# forwar prop
def L_layer_forward_prop(X, parameters):
    A = X
    L = len(parameters) // 2    #no of layers in the neural network

    for l in range(1, L+1):
        A_prev = A
        w1 = parameters["w" + str(l)]
        b1 = parameters["b" + str(l)]

        print("A"+str(l-1)+": ", A_prev)
        print("w"+str(l)+": ", w1)
        print("b"+str(l)+": ", b1)
        print("--"*20)

        A = linear_forward(A_prev, w1, b1)
        print("A"+str(l)+": ", A)
        print("**"*20)

    return A, A_prev

# %%
# initializing the parameters
parameters = initialize_params([2,2,1])

# %%
# example of 1st student
X = df[["cgpa", "resume_score"]].values[0].reshape(2,1) # Shape(no of features, no. of training example)
y = df[["lpa"]].values[0][0]


y_hat, A1 = L_layer_forward_prop(X, parameters)


y_hat = y_hat[0][0]
print("y_hat = ", y_hat)
# Out:
# A0:  [[8]
#  [8]]
# w1:  [[0.1 0.1]
#  [0.1 0.1]]
# b1:  [[0.]
#  [0.]]
# ----------------------------------------
# A1:  [[1.6]
#  [1.6]]
# ****************************************
# A1:  [[1.6]
#  [1.6]]
# w2:  [[0.1]
#  [0.1]]
# b2:  [[0.]]
# ----------------------------------------
# A2:  [[0.32]]
# ****************************************
# y_hat =  0.32000000000000006

# %%
# update weights and bias
def update_parameters(parameters, y, y_hat, A1, X):
    parameters["w2"][0][0] = parameters["w2"][0][0] + (0.001 * 2 *(y-y_hat) * A1[0][0])
    parameters["w2"][1][0] = parameters["w2"][1][0] + (0.001 * 2 *(y-y_hat) * A1[1][0])
    parameters["b2"][0][0] = parameters["b2"][0][0] + (0.001 * 2 *(y-y_hat))

    parameters["w1"][0][0] = parameters["w1"][0][0] + (0.001 * 2 *(y-y_hat) * parameters["w2"][0][0] * X[0][0])
    parameters["w1"][0][1] = parameters["w1"][0][1] + (0.001 * 2 *(y-y_hat) * parameters["w2"][0][0] * X[1][0])
    parameters["b1"][0][0] = parameters["b1"][0][0] + (0.001 * 2 *(y-y_hat) * parameters["w2"][0][0])

    parameters["w1"][1][0] = parameters["w1"][1][0] + (0.001 * 2 *(y-y_hat) * parameters["w2"][1][0] * X[0][0])
    parameters["w1"][1][1] = parameters["w1"][1][1] + (0.001 * 2 *(y-y_hat) * parameters["w2"][1][0] * X[1][0])
    parameters["b1"][1][0] = parameters["b1"][1][0] + (0.001 * 2 *(y-y_hat) * parameters["w2"][1][0])

# %%
# # update weights and bias
# def update_parameters(parameters, y, y_hat, A1, X, lr=0.001):
#     error = 2 * (y - y_hat)

#     parameters["w2"][0][0] = parameters["w2"][0][0].item() + lr * error * A1[0][0].item()
#     parameters["w2"][1][0] = parameters["w2"][1][0].item() + lr * error * A1[1][0].item()
#     parameters["b2"][0][0] = parameters["b2"][0][0].item() + lr * error

#     parameters["w1"][0][0] = parameters["w1"][0][0].item() + lr * error * parameters["w2"][0][0].item() * X[0][0].item()
#     parameters["w1"][0][1] = parameters["w1"][0][1].item() + lr * error * parameters["w2"][0][0].item() * X[1][0].item()
#     parameters["b1"][0][0] = parameters["b1"][0][0].item() + lr * error * parameters["w2"][0][0].item()

#     parameters["w1"][1][0] = parameters["w1"][1][0].item() + lr * error * parameters["w2"][1][0].item() * X[0][0].item()
#     parameters["w1"][1][1] = parameters["w1"][1][1].item() + lr * error * parameters["w2"][1][0].item() * X[1][0].item()
#     parameters["b1"][1][0] = parameters["b1"][1][0].item() + lr * error * parameters["w2"][1][0].item()

# %%
update_parameters(parameters, y, y_hat, A1, X)

parameters
# Out:
# {'w1': array([[0.10658137, 0.10658137],
#         [0.10658137, 0.10658137]]),
#  'b1': array([[0.00082267],
#         [0.00082267]]),
#  'w2': array([[0.111776],
#         [0.111776]]),
#  'b2': array([[0.00736]])}

# %%
# example of 2nd student
X = df[["cgpa", "resume_score"]].values[1].reshape(2,1)
y = df[["lpa"]].values[1][0]


y_hat, A1 = L_layer_forward_prop(X, parameters)

y_hat = y_hat[0][0]
print("y_hat = ", y_hat)
# Out:
# y_hat =  0.38876756779532284

# %%
update_parameters(parameters, y, y_hat, A1, X)

parameters
# Out:
# {'w1': array([[0.11481311, 0.11716504],
#         [0.11481311, 0.11716504]]),
#  'b1': array([[0.00199863],
#         [0.00199863]]),
#  'w2': array([[0.12751067],
#         [0.12751067]]),
#  'b2': array([[0.01658246]])}

# %%
# example of 3rd student
X = df[["cgpa", "resume_score"]].values[2].reshape(2,1)
y = df[["lpa"]].values[2][0]


y_hat, A1 = L_layer_forward_prop(X, parameters)

y_hat = y_hat[0][0]
print("y_hat = ", y_hat)
# Out:
# y_hat =  0.49036719436206533

# %%
update_parameters(parameters, y, y_hat, A1, X)

parameters
# Out:
# {'w1': array([[0.12458335, 0.13344878],
#         [0.12461077, 0.13349447]]),
#  'b1': array([[0.00362701],
#         [0.00363158]]),
#  'w2': array([[0.1477752 ],
#         [0.14818986]]),
#  'b2': array([[0.02760173]])}

# %%
# example of 4th student
X = df[["cgpa", "resume_score"]].values[3].reshape(2,1)
y = df[["lpa"]].values[3][0]


y_hat, A1 = L_layer_forward_prop(X, parameters)

y_hat = y_hat[0][0]
print("y_hat = ", y_hat)
# Out:
# y_hat =  0.6779691950157402

# %%
update_parameters(parameters, y, y_hat, A1, X)

parameters
# Out:
# {'w1': array([[0.13562189, 0.15994127],
#         [0.13579618, 0.16033944]]),
#  'b1': array([[0.00583472],
#         [0.00586866]]),
#  'w2': array([[0.17460429],
#         [0.1769274 ]]),
#  'b2': array([[0.04024579]])}

# %%
# epochs implementation

parameters = initialize_params([2,2,1])
epochs = 5

for i in range(epochs):

  Loss = []

  for j in range(df.shape[0]):

    X = df[['cgpa', 'resume_score']].values[j].reshape(2,1) # Shape(no of features, no. of training example)
    y = df[['lpa']].values[j][0]

    # Parameter initialization


    y_hat,A1 = L_layer_forward_prop(X,parameters)
    y_hat = y_hat[0][0]

    update_parameters(parameters,y,y_hat,A1,X)

    Loss.append((y-y_hat)**2)

  print('Epoch - ',i+1,'Loss - ',np.array(Loss).mean())

parameters
# Out:
# Epoch -  1 Loss -  26.28249792398698
# Epoch -  2 Loss -  19.438253848220803
# Epoch -  3 Loss -  10.139874435827522
# Epoch -  4 Loss -  3.385561305106485
# Epoch -  5 Loss -  1.3198454128484565
# {'w1': array([[0.273603  , 0.3993222 ],
#         [0.28787155, 0.42586102]]),
#  'b1': array([[0.02885522],
#         [0.03133223]]),
#  'w2': array([[0.42574893],
#         [0.50219328]]),
#  'b2': array([[0.11841278]])}
